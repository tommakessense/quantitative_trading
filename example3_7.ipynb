# %% [markdown]
# # Simple Mean-Reverting Model with Open-to-Open Reversion (and Transaction Costs)

# %%
import numpy as np

# %%
import pandas as pd

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
import yfinance as yf

# %% [markdown]
# ## Universe: current S&P 400 MidCap constituents, open prices from yfinance (open-to-open reversion, traded at the open like in example3_8, to avoid overnight slippage)

# %%
startDate='2006-01-01'

# %%
endDate='2006-12-31'

# %%
def get_sp400_tickers():
    url = 'https://en.wikipedia.org/wiki/List_of_S%26P_400_companies'
    resp = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'}, timeout=30)
    soup = BeautifulSoup(resp.text, 'html.parser')
    table = soup.find('table', {'id': 'constituents'})
    rows = table.find_all('tr')[1:]
    return [row.find_all('td')[0].get_text(strip=True).replace('.', '-') for row in rows]

# %%
tickers=get_sp400_tickers()

# %%
def download_open_prices(tickers, start, end):
    data = yf.download(tickers, start=start, end=end, auto_adjust=False, threads=True, progress=False)
    return data['Open']

# %%
# download extra history before startDate so the first daily return in the analysis window isn't NaN
downloadStart=(pd.Timestamp(startDate)-pd.Timedelta(days=30)).strftime('%Y-%m-%d')
downloadEnd=(pd.Timestamp(endDate)+pd.Timedelta(days=1)).strftime('%Y-%m-%d')
df=download_open_prices(tickers, downloadStart, downloadEnd)
# Out:
# $BHF: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $KD: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $P: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $AMH: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $HLI: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $BILL: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $PLNT: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $CPRI: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $ESNT: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $TRU: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $CG: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $HLNE: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $MEDP: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $BRX: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $H: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $PATH: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $HGV: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $CART: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $SARO: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $MTDR: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $CHRD: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $SN: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $GWRE: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $STAG: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $FBIN: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $VOYA: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $LEA: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $FN: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $ALLY: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $DT: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $MUSA: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $CNM: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $HQY: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $PCTY: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $SHC: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $GMED: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $STWD: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $AM: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $LNTH: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $POST: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $DOCU: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $DUOL: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $SFM: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $CELH: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $BROS: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $WMS: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $CRBG: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $ELAN: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $ARMK: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $WMG: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $ALGM: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $AVAV: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $NTNX: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $AVTR: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $BAH: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $MTSI: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $SITM: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $BWXT: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $NXT: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $OLLI: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $FND: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $CR: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $ALSN: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $PEN: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $AXTA: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $LIVN: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $DOCN: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $ULS: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $LOPE: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $DOCS: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $RGA: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $CHWY: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $WING: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $SAIC: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $AR: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $GLPI: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $RH: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $PK: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $TWLO: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $KNSL: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $PRI: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $ROKU: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $ESAB: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $DTM: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $EQH: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $QLYS: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $WH: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $TLN: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $APPF: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $PR: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $APG: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $BTSG: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $PINS: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $NVST: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $ACI: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $CNH: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $BJ: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $BSY: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $TOST: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $PBF: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $VVV: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $CTRE: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $HIMS: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $USFD: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $PFGC: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $ROIV: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $KNF: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $MP: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $NVT: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $DBX: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $KRYS: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $ENSG: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $SOLS: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $VNT: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $AHR: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $NWE: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $FIVE: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $G: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $REXR: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $RYAN: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $ELF: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $WFRD: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $YETI: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $PSN: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $GXO: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $OGS: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $ST: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $BURL: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $VC: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $FOUR: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $JAZZ: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $FAF: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $OKTA: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $IRT: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $VNOM: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $ACM: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $VAL: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $CAVA: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# $ONTO: Data doesn't exist for startDate = 1133499600, endDate = 1167627600
# 139 Failed downloads:
# ['BHF', 'KD', 'P', 'AMH', 'HLI', 'BILL', 'PLNT', 'CPRI', 'ESNT', 'TRU', 'CG', 'HLNE', 'MEDP', 'BRX', 'H', 'PATH', 'HGV', 'CART', 'SARO', 'MTDR', 'CHRD', 'SN', 'GWRE', 'STAG', 'FBIN', 'VOYA', 'LEA', 'FN', 'ALLY', 'DT', 'MUSA', 'CNM', 'HQY', 'PCTY', 'SHC', 'GMED', 'STWD', 'AM', 'LNTH', 'POST', 'DOCU', 'DUOL', 'SFM', 'CELH', 'BROS', 'WMS', 'CRBG', 'ELAN', 'ARMK', 'WMG', 'ALGM', 'AVAV', 'NTNX', 'AVTR', 'BAH', 'MTSI', 'SITM', 'BWXT', 'NXT', 'OLLI', 'FND', 'CR', 'ALSN', 'PEN', 'AXTA', 'LIVN', 'DOCN', 'ULS', 'LOPE', 'DOCS', 'RGA', 'CHWY', 'WING', 'SAIC', 'AR', 'GLPI', 'RH', 'PK', 'TWLO', 'KNSL', 'PRI', 'ROKU', 'ESAB', 'DTM', 'EQH', 'QLYS', 'WH', 'TLN', 'APPF', 'PR', 'APG', 'BTSG', 'PINS', 'NVST', 'ACI', 'CNH', 'BJ', 'BSY', 'TOST', 'PBF', 'VVV', 'CTRE', 'HIMS', 'USFD', 'PFGC', 'ROIV', 'KNF', 'MP', 'NVT', 'DBX', 'KRYS', 'ENSG', 'SOLS', 'VNT', 'AHR', 'NWE', 'FIVE', 'G', 'REXR', 'RYAN', 'ELF', 'WFRD', 'YETI', 'PSN', 'GXO', 'OGS', 'ST', 'BURL', 'VC', 'FOUR', 'JAZZ', 'FAF', 'OKTA', 'IRT', 'VNOM', 'ACM', 'VAL', 'CAVA', 'ONTO']: Data doesn't exist for startDate = 1133499600, endDate = 1167627600

# %%
df.sort_index(inplace=True)

# %%
dailyret=df.pct_change()

# %%
marketDailyret=dailyret.mean(axis=1)

# %%
weights=-(np.array(dailyret)-np.array(marketDailyret).reshape((dailyret.shape[0], 1)))

# %%
wtsum=np.nansum(abs(weights), axis=1)

# %%
weights[wtsum==0,]=0

# %%
wtsum[wtsum==0]=1

# %%
weights=weights/wtsum.reshape((dailyret.shape[0],1))

# %%
dailypnl=np.nansum(np.array(pd.DataFrame(weights).shift())*np.array(dailyret), axis=1)

# %%
dailypnl=dailypnl[np.logical_and(df.index >= startDate, df.index <= endDate)]

# %%
sharpeRatio=np.sqrt(252)*np.mean(dailypnl)/np.std(dailypnl)

# %%
sharpeRatio
# Out:
# np.float64(4.282217132605728)

# %% [markdown]
# # With transaction costs

# %%
onewaytcost=0.0005

# %%
weights=weights[np.logical_and(df.index >= startDate, df.index <= endDate)]

# %%
dailypnlminustcost=dailypnl - (np.nansum(abs(weights-np.array(pd.DataFrame(weights).shift())), axis=1)*onewaytcost)

# %%
sharpeRatioMinusTcost=np.sqrt(252)*np.mean(dailypnlminustcost)/np.std(dailypnlminustcost)

# %%
sharpeRatioMinusTcost
# Out:
# np.float64(1.905512885156893)
